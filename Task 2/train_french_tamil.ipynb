# %%
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
import pickle

# Load the dataset
data = pd.read_csv("french_tamil.csv")

# Tokenize French and Tamil words
french_tokenizer = Tokenizer(char_level=True)  # Tokenize by characters
tamil_tokenizer = Tokenizer(char_level=True)

french_tokenizer.fit_on_texts(data['French'])
tamil_tokenizer.fit_on_texts(data['Tamil'])

# Convert text to sequences
french_sequences = french_tokenizer.texts_to_sequences(data['French'])
tamil_sequences = tamil_tokenizer.texts_to_sequences(data['Tamil'])

# Pad the sequences
french_padded = pad_sequences(french_sequences, maxlen=6, padding='post')
tamil_padded = pad_sequences(tamil_sequences, maxlen=8, padding='post')

# Convert Tamil sequences into class indices
y_data = tamil_padded.argmax(axis=-1)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(french_padded, y_data, test_size=0.2, random_state=42)

# Build the model
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=len(french_tokenizer.word_index) + 1, output_dim=16, input_length=6),
    tf.keras.layers.LSTM(64, return_sequences=True),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(len(tamil_tokenizer.word_index) + 1, activation='softmax')  # Output size matches Tamil vocabulary
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=50, validation_data=(X_test, y_test))

# Save the trained model
model.save("french_to_tamil_model.h5")

# Save the tokenizers for later use in the GUI
with open('french_tokenizer.pkl', 'wb') as f:
    pickle.dump(french_tokenizer, f)

with open('tamil_tokenizer.pkl', 'wb') as f:
    pickle.dump(tamil_tokenizer, f)
# Out:
# Epoch 1/50
# c:\Users\HP\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step - accuracy: 0.0000e+00 - loss: 3.0908 - val_accuracy: 0.0000e+00 - val_loss: 3.0862
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.6250 - loss: 3.0818 - val_accuracy: 0.0000e+00 - val_loss: 3.0821
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.6250 - loss: 3.0715 - val_accuracy: 0.0000e+00 - val_loss: 3.0770
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.6250 - loss: 3.0597 - val_accuracy: 0.0000e+00 - val_loss: 3.0710
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.6250 - loss: 3.0463 - val_accuracy: 0.0000e+00 - val_loss: 3.0641
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.6250 - loss: 3.0308 - val_accuracy: 0.0000e+00 - val_loss: 3.0561
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.6250 - loss: 3.0129 - val_accuracy: 0.0000e+00 - val_loss: 3.0465
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.6250 - loss: 2.9919 - val_accuracy: 0.0000e+00 - val_loss: 3.0351
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step - accuracy: 0.6250 - loss: 2.9673 - val_accuracy: 0.0000e+00 - val_loss: 3.0214
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.6250 - loss: 2.9381 - val_accuracy: 0.0000e+00 - val_loss: 3.0048
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.6250 - loss: 2.9035 - val_accuracy: 0.0000e+00 - val_loss: 2.9848
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.6250 - loss: 2.8621 - val_accuracy: 0.0000e+00 - val_loss: 2.9607
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.6250 - loss: 2.8126 - val_accuracy: 0.0000e+00 - val_loss: 2.9316
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.6250 - loss: 2.7532 - val_accuracy: 0.0000e+00 - val_loss: 2.8966
# Epoch 15/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.6250 - loss: 2.6819 - val_accuracy: 0.0000e+00 - val_loss: 2.8547
# Epoch 16/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6250 - loss: 2.5962 - val_accuracy: 0.0000e+00 - val_loss: 2.8050
# Epoch 17/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.6250 - loss: 2.4934 - val_accuracy: 0.0000e+00 - val_loss: 2.7467
# Epoch 18/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.6250 - loss: 2.3705 - val_accuracy: 0.0000e+00 - val_loss: 2.6798
# Epoch 19/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.6250 - loss: 2.2254 - val_accuracy: 0.0000e+00 - val_loss: 2.6051
# Epoch 20/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.6250 - loss: 2.0570 - val_accuracy: 0.0000e+00 - val_loss: 2.5268
# Epoch 21/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.6250 - loss: 1.8676 - val_accuracy: 0.0000e+00 - val_loss: 2.4550
# Epoch 22/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.6250 - loss: 1.6672 - val_accuracy: 0.0000e+00 - val_loss: 2.4088
# Epoch 23/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.6250 - loss: 1.4774 - val_accuracy: 0.0000e+00 - val_loss: 2.4182
# Epoch 24/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.6250 - loss: 1.3334 - val_accuracy: 0.0000e+00 - val_loss: 2.5120
# Epoch 25/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.6250 - loss: 1.2702 - val_accuracy: 0.0000e+00 - val_loss: 2.6756
# Epoch 26/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.6250 - loss: 1.2873 - val_accuracy: 0.0000e+00 - val_loss: 2.8293
# Epoch 27/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.6250 - loss: 1.3343 - val_accuracy: 0.0000e+00 - val_loss: 2.8978
# Epoch 28/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.6250 - loss: 1.3599 - val_accuracy: 0.0000e+00 - val_loss: 2.8616
# Epoch 29/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.6250 - loss: 1.3472 - val_accuracy: 0.0000e+00 - val_loss: 2.7399
# Epoch 30/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.6250 - loss: 1.3023 - val_accuracy: 0.0000e+00 - val_loss: 2.5648
# Epoch 31/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.6250 - loss: 1.2398 - val_accuracy: 0.0000e+00 - val_loss: 2.3683
# Epoch 32/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.6250 - loss: 1.1751 - val_accuracy: 0.0000e+00 - val_loss: 2.1767
# Epoch 33/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.6250 - loss: 1.1209 - val_accuracy: 0.0000e+00 - val_loss: 2.0083
# Epoch 34/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6250 - loss: 1.0846 - val_accuracy: 0.0000e+00 - val_loss: 1.8725
# Epoch 35/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.6250 - loss: 1.0675 - val_accuracy: 0.0000e+00 - val_loss: 1.7713
# Epoch 36/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.6250 - loss: 1.0652 - val_accuracy: 0.0000e+00 - val_loss: 1.7020
# Epoch 37/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.6250 - loss: 1.0708 - val_accuracy: 0.0000e+00 - val_loss: 1.6598
# Epoch 38/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.6250 - loss: 1.0780 - val_accuracy: 0.0000e+00 - val_loss: 1.6397
# Epoch 39/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6250 - loss: 1.0818 - val_accuracy: 0.0000e+00 - val_loss: 1.6377
# Epoch 40/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.6250 - loss: 1.0798 - val_accuracy: 0.0000e+00 - val_loss: 1.6509
# Epoch 41/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.6250 - loss: 1.0714 - val_accuracy: 0.0000e+00 - val_loss: 1.6773
# Epoch 42/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.6250 - loss: 1.0575 - val_accuracy: 0.0000e+00 - val_loss: 1.7157
# Epoch 43/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.6250 - loss: 1.0398 - val_accuracy: 0.0000e+00 - val_loss: 1.7653
# Epoch 44/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.6250 - loss: 1.0208 - val_accuracy: 0.0000e+00 - val_loss: 1.8248
# Epoch 45/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.6250 - loss: 1.0031 - val_accuracy: 0.0000e+00 - val_loss: 1.8922
# Epoch 46/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - accuracy: 0.6250 - loss: 0.9890 - val_accuracy: 0.0000e+00 - val_loss: 1.9642
# Epoch 47/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.6250 - loss: 0.9800 - val_accuracy: 0.0000e+00 - val_loss: 2.0354
# Epoch 48/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.6250 - loss: 0.9762 - val_accuracy: 0.0000e+00 - val_loss: 2.0997
# Epoch 49/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.6250 - loss: 0.9763 - val_accuracy: 0.0000e+00 - val_loss: 2.1502
# Epoch 50/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.6250 - loss: 0.9778 - val_accuracy: 0.0000e+00 - val_loss: 2.1814
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
